-- %%
DESCRIBE STORAGE CREDENTIAL rio_dataengineering;

-- %%
CREATE EXTERNAL LOCATION people_data
URL 'abfss://people-data@peopleanalyticslakedomma.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL rio_dataengineering);

-- %%
CREATE SCHEMA IF NOT EXISTS rio_dataengineering.bronze;
